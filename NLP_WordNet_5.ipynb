# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamrana238/NLP/blob/main/NLP_WordNet_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 12
# ##Write a program to read text data from a file and perform pre-processing, Word Sense Disambiguation and list of synonyms, antonyms, hypernyms and hyponyms of every word as obtained from the lexical ontology WordNet.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)

# %%
import nltk
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_rus.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/maxent_treebank_pos_tagger_tab.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets_json.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
def preprocess(text):
  tokens = word_tokenize(text)
  words = [word.lower() for word in tokens if word.isalpha()]
  lemmatizer = WordNetLemmatizer()
  words = [lemmatizer.lemmatize(word) for word in words]

  return words

# %%
def word_sense_disambiguation(word):
  synsets = wordnet.synsets(word)
  if synsets:
    return synsets[0]
  else:
    return None

# %%
def get_word_info(word):
  sense = word_sense_disambiguation(word)

  if sense:
    synonyms = [lemma.name() for lemma in sense.lemmas()]
    antonyms = []

    for lemma in sense.lemmas():
      antonyms.extend(lemma.antonyms())

    antonyms = [antonym.name() for antonym in antonyms]

    hypernyms = [hypernym.name() for hypernym in sense.hypernyms()]

    hyponyms = [hyponym.name() for hyponym in sense.hyponyms()]

    return {
        'Synonyms': synonyms,
        'Antonyms': antonyms,
        'Hypernyms': hypernyms,
        'Hyponyms': hyponyms
    }

  else:
    return None

# %%
def main(file_path):
  with open(file_path, 'r', encoding = 'utf-8') as file:
    text = file.read()

  words = preprocess(text)

  word_info_dict = {}
  for word in words:
    if word not in word_info_dict:
      word_info = get_word_info(word)
      if word_info:
        word_info_dict[word] = word_info

  for word, info in word_info_dict.items():
    print(f"Word: {word}")
    print(f"Synonyms: {','.join(info['Synonyms'])}")
    print(f"Antonyms: {','.join(info['Antonyms'])}")
    print(f"Hypernyms: {','.join(info['Hypernyms'])}")
    print(f"Hyponyms: {','.join(info['Hyponyms'])}")
    print("\n")

# %%
if __name__ == "__main__":
  main('Story.txt')
# Out:
# Word: once
# Synonyms: once,one_time,in_one_case
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: a
# Synonyms: angstrom,angstrom_unit,A
# Antonyms:
# Hypernyms: metric_linear_unit.n.01
# Hyponyms:
#
#
# Word: time
# Synonyms: time,clip
# Antonyms:
# Hypernyms: case.n.01
# Hyponyms:
#
#
# Word: in
# Synonyms: inch,in
# Antonyms:
# Hypernyms: linear_unit.n.01
# Hyponyms:
#
#
# Word: quiet
# Synonyms: lull,quiet
# Antonyms:
# Hypernyms: calmness.n.02
# Hyponyms:
#
#
# Word: little
# Synonyms: little
# Antonyms:
# Hypernyms: small_indefinite_quantity.n.01
# Hyponyms:
#
#
# Word: village
# Synonyms: village,small_town,settlement
# Antonyms:
# Hypernyms: community.n.01
# Hyponyms: moshav.n.01
#
#
# Word: nestled
# Synonyms: cuddle,snuggle,nestle,nest,nuzzle,draw_close
# Antonyms:
# Hypernyms: cling_to.v.01
# Hyponyms:
#
#
# Word: between
# Synonyms: between,betwixt
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: towering
# Synonyms: loom,tower,predominate,hulk
# Antonyms:
# Hypernyms: rise.v.04
# Hyponyms:
#
#
# Word: mountain
# Synonyms: mountain,mount
# Antonyms:
# Hypernyms: natural_elevation.n.01
# Hyponyms: alp.n.01,ben.n.01,seamount.n.01,volcano.n.02
#
#
# Word: shimmering
# Synonyms: shimmer
# Antonyms:
# Hypernyms: shine.v.02
# Hyponyms:
#
#
# Word: lake
# Synonyms: lake
# Antonyms:
# Hypernyms: body_of_water.n.01
# Hyponyms: bayou.n.01,lagoon.n.01,loch.n.02,lough.n.02,oxbow_lake.n.01,pond.n.01,reservoir.n.02,tarn.n.01
#
#
# Word: there
# Synonyms: there
# Antonyms: here
# Hypernyms: location.n.01
# Hyponyms:
#
#
# Word: lived
# Synonyms: populate,dwell,live,inhabit
# Antonyms:
# Hypernyms: be.v.03
# Hyponyms: board.v.02,camp.v.01,cohabit.v.01,lodge.v.01,neighbor.v.01,nest.v.01,occupy.v.02,overpopulate.v.01,people.v.02,reside.v.01,tenant.v.01
#
#
# Word: young
# Synonyms: young,offspring
# Antonyms:
# Hypernyms: animal.n.01
# Hyponyms: hatchling.n.01,orphan.n.04,spat.n.03,young_bird.n.01,young_fish.n.01,young_mammal.n.01
#
#
# Word: girl
# Synonyms: girl,miss,missy,young_lady,young_woman,fille
# Antonyms:
# Hypernyms: woman.n.01
# Hyponyms: baby.n.05,belle.n.01,bimbo.n.01,chachka.n.01,chit.n.01,colleen.n.01,dame.n.01,flapper.n.01,gal.n.03,gamine.n.02,gibson_girl.n.01,lass.n.01,maid.n.02,may_queen.n.01,mill-girl.n.01,party_girl.n.01,peri.n.01,ring_girl.n.01,rosebud.n.02,sex_kitten.n.01,shop_girl.n.01,soubrette.n.01,sweater_girl.n.01,tomboy.n.01,valley_girl.n.01,working_girl.n.01
#
#
# Word: named
# Synonyms: name,call
# Antonyms:
# Hypernyms: label.v.01
# Hyponyms: baptize.v.01,dub.v.01,entitle.v.02,refer.v.07,rename.v.01,style.v.01,tag.v.03,term.v.01
#
#
# Word: wa
# Synonyms: Washington,Evergreen_State,WA
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: known
# Synonyms: know,cognize,cognise
# Antonyms: ignore
# Hypernyms:
# Hyponyms: keep_track.v.01,recognize.v.02
#
#
# Word: throughout
# Synonyms: throughout,end-to-end
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: boundless
# Synonyms: boundless,unbounded,limitless
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: curiosity
# Synonyms: curiosity,wonder
# Antonyms:
# Hypernyms: cognitive_state.n.01
# Hyponyms: curiousness.n.01,desire_to_know.n.01,interest.n.01
#
#
# Word: love
# Synonyms: love
# Antonyms: hate
# Hypernyms: emotion.n.01
# Hyponyms: agape.n.01,agape.n.02,amorousness.n.01,ardor.n.02,benevolence.n.01,devotion.n.01,filial_love.n.01,heartstrings.n.01,lovingness.n.01,loyalty.n.02,puppy_love.n.01,worship.n.02
#
#
# Word: exploring
# Synonyms: research,search,explore
# Antonyms:
# Hypernyms: investigate.v.01
# Hyponyms: cast_about.v.01,google.v.01,mapquest.v.01,prospect.v.02,re-explore.v.01
#
#
# Word: wood
# Synonyms: wood
# Antonyms:
# Hypernyms: plant_material.n.01
# Hyponyms: alder.n.01,ash.n.03,balsa.n.01,bamboo.n.01,basswood.n.01,beech.n.02,beefwood.n.02,bentwood.n.01,birch.n.01,black_locust.n.01,blackwood.n.01,boxwood.n.01,brazilwood.n.01,briarwood.n.01,brushwood.n.01,burl.n.01,cabinet_wood.n.01,cedar.n.02,cherry.n.01,chestnut.n.01,citronwood.n.01,cocuswood.n.01,cypress.n.01,dogwood.n.02,driftwood.n.01,dyewood.n.01,ebony.n.02,elm.n.02,eucalyptus.n.01,fir.n.01,fruitwood.n.01,granadilla_wood.n.01,guaiac_wood.n.01,gumwood.n.01,hardwood.n.01,hazel.n.02,heartwood.n.01,hemlock.n.03,hickory.n.01,incense_wood.n.01,ironwood.n.02,kauri.n.03,kingwood.n.01,knot.n.03,lancewood.n.01,larch.n.01,lemonwood.n.01,lignum_vitae.n.01,locust.n.02,log.n.01,logwood.n.01,mahogany.n.01,maple.n.01,matchwood.n.01,matchwood.n.02,oak.n.01,obeche.n.01,olive.n.03,orangewood.n.01,panama_redwood.n.01,pecan.n.01,pine.n.02,poon.n.01,poplar.n.01,pyinma.n.01,raw_wood.n.01,red_lauan.n.01,redwood.n.01,rosewood.n.01,ruby_wood.n.01,sabicu.n.01,sandalwood.n.01,sandarac.n.01,sapwood.n.01,satinwood.n.02,sawdust.n.01,shittimwood.n.03,silver_quandong.n.01,softwood.n.01,spruce.n.01,sumac.n.01,sycamore.n.01,teak.n.01,tulipwood.n.01,tulipwood.n.02,tupelo.n.01,walnut.n.02,wicker.n.01,yellowwood.n.01,yew.n.01,zebrawood.n.01
#
#
# Word: surrounded
# Synonyms: surround,environ,ring,skirt,border
# Antonyms:
# Hypernyms: touch.v.05
# Hyponyms: cloister.v.01,cloister.v.02,enclose.v.03,fringe.v.02,girdle.v.02,hem_in.v.01
#
#
# Word: home
# Synonyms: home,place
# Antonyms:
# Hypernyms: residence.n.01
# Hyponyms: home_away_from_home.n.01
#
#
# Word: every
# Synonyms: every
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: day
# Synonyms: day,twenty-four_hours,twenty-four_hour_period,24-hour_interval,solar_day,mean_solar_day
# Antonyms:
# Hypernyms: time_unit.n.01
# Hyponyms: date.n.01,date.n.07,eve.n.02,morrow.n.01,today.n.02,tomorrow.n.01,yesterday.n.01
#
#
# Word: after
# Synonyms: after
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: chore
# Synonyms: job,task,chore
# Antonyms:
# Hypernyms: duty.n.02
# Hyponyms: ball-buster.n.02,scut_work.n.01,stint.n.03
#
#
# Word: were
# Synonyms: be
# Antonyms:
# Hypernyms:
# Hyponyms: abound.v.01,accept.v.08,account.v.01,account_for.v.01,act.v.06,answer.v.06,appear.v.04,bake.v.04,balance.v.04,be_well.v.01,beat.v.12,begin.v.06,begin.v.07,belong.v.01,belong.v.02,belong.v.04,belong.v.05,breathe.v.04,buy.v.03,clean.v.05,cohere.v.03,come_in_for.v.01,come_in_handy.v.01,compact.v.01,compare.v.02,confuse.v.02,connect.v.07,consist.v.02,consist.v.04,contain.v.04,contain.v.05,continue.v.10,cost.v.01,count.v.02,count.v.07,cover.v.18,cut.v.25,cut_across.v.02,deck.v.01,depend.v.01,deserve.v.01,disagree.v.02,distribute.v.09,diverge.v.02,draw.v.21,end.v.03,fall.v.04,fall.v.16,feel.v.04,figure.v.02,fit.v.07,gape.v.02,go.v.10,gravitate.v.02,hail.v.02,hang.v.06,head.v.04,hold.v.17,hoodoo.v.01,hum.v.02,impend.v.01,incarnate.v.02,iridesce.v.01,jumble.v.01,kill.v.04,lend.v.03,let_go.v.02,lie.v.04,litter.v.01,loiter.v.01,look.v.02,look.v.03,lubricate.v.01,make.v.31,make_sense.v.01,measure.v.03,mope.v.02,object.v.02,osculate.v.01,owe.v.03,pay.v.07,point.v.10,press.v.08,promise.v.04,prove.v.01,put_out.v.06,rage.v.02,range.v.01,rank.v.01,rate.v.02,recognize.v.08,relate.v.04,remain.v.03,represent.v.03,rest.v.01,retard.v.02,run.v.05,run_into.v.01,rut.v.01,seem.v.03,seethe.v.02,sell.v.02,sell.v.06,sell.v.07,shine.v.04,shine.v.05,sparkle.v.02,specify.v.03,squat.v.02,stagnate.v.01,stagnate.v.03,stand.v.02,stand.v.03,stand_by.v.03,stay.v.01,stay.v.04,stick.v.04,stink.v.01,subtend.v.01,suck.v.04,suffer.v.06,suffer.v.08,suit.v.02,swim.v.03,swim.v.04,swing.v.10,tend.v.01,test.v.04,total.v.01,translate.v.07,transplant.v.02,trim.v.05,underlie.v.01,want.v.02,wash.v.05,wind.v.02,work.v.14
#
#
# Word: done
# Synonyms: make,do
# Antonyms:
# Hypernyms:
# Hyponyms: overdo.v.01
#
#
# Word: set
# Synonyms: set
# Antonyms:
# Hypernyms: collection.n.01
# Hyponyms: bracket.n.01,chess_set.n.01,choir.n.02,conjugation.n.03,core.n.01,dentition.n.02,field.n.12,field.n.13,field.n.15,intersection.n.04,manicure_set.n.01,octet.n.03,pair.n.01,portfolio.n.02,quartet.n.03,quintet.n.04,score.n.04,septet.n.03,sextet.n.04,singleton.n.02,suite.n.04,synset.n.01,threescore.n.01,trio.n.04,union.n.08
#
#
# Word: out
# Synonyms: out
# Antonyms:
# Hypernyms: failure.n.01
# Hyponyms: putout.n.01,strikeout.n.01
#
#
# Word: brown
# Synonyms: brown,brownness
# Antonyms:
# Hypernyms: chromatic_color.n.01
# Hyponyms: chestnut.n.04,chocolate.n.03,hazel.n.04,light_brown.n.01,mocha.n.04,olive_brown.n.01,puce.n.01,reddish_brown.n.01,taupe.n.01,vandyke_brown.n.01,yellowish_brown.n.01
#
#
# Word: satchel
# Synonyms: satchel
# Antonyms:
# Hypernyms: baggage.n.01
# Hyponyms:
#
#
# Word: filled
# Synonyms: fill,fill_up,make_full
# Antonyms: empty
# Hypernyms: change.v.01
# Hyponyms: brim.v.02,clog.v.06,clutter.v.01,complete.v.02,deluge.v.01,electrify.v.02,farce.v.01,heap.v.03,impregnate.v.01,impregnate.v.02,ink.v.03,line.v.05,load.v.01,load.v.02,lubricate.v.02,overfill.v.01,pack.v.02,pad.v.04,populate.v.02,prime.v.03,replenish.v.01,stuff.v.06,surcharge.v.05,top_off.v.02
#
#
# Word: snack
# Synonyms: bite,collation,snack
# Antonyms:
# Hypernyms: meal.n.01
# Hyponyms: coffee_break.n.01,nosh.n.01,refreshment.n.01
#
#
# Word: notebook
# Synonyms: notebook
# Antonyms:
# Hypernyms: book.n.02
# Hyponyms: commonplace_book.n.01,jotter.n.01,playbook.n.01
#
#
# Word: quill
# Synonyms: quill,quill_pen
# Antonyms:
# Hypernyms: pen.n.01
# Hyponyms:
#
#
# Word: ready
# Synonyms: ready
# Antonyms:
# Hypernyms: readiness.n.01
# Hyponyms:
#
#
# Word: jot
# Synonyms: jotting,jot
# Antonyms:
# Hypernyms: note.n.01
# Hyponyms:
#
#
# Word: down
# Synonyms: down,down_feather
# Antonyms:
# Hypernyms: feather.n.01
# Hyponyms: duck_down.n.01,goose_down.n.01,plumule.n.01,swan's_down.n.02
#
#
# Word: whatever
# Synonyms: any,whatever,whatsoever
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: interesting
# Synonyms: interest
# Antonyms: bore
# Hypernyms: arouse.v.01
# Hyponyms: absorb.v.09,fascinate.v.02
#
#
# Word: thing
# Synonyms: thing
# Antonyms:
# Hypernyms: situation.n.01
# Hyponyms:
#
#
# Word: might
# Synonyms: might,mightiness,power
# Antonyms:
# Hypernyms: strength.n.01
# Hyponyms:
#
#
# Word: discover
# Synonyms: detect,observe,find,discover,notice
# Antonyms:
# Hypernyms: spy.v.03
# Hyponyms: find_out.v.04,instantiate.v.02,see.v.19,sense.v.02,trace.v.05
#
#
# Word: one
# Synonyms: one,1,I,ace,single,unity
# Antonyms:
# Hypernyms: digit.n.01
# Hyponyms: monad.n.02,singleton.n.01
#
#
# Word: crisp
# Synonyms: chip,crisp,potato_chip,Saratoga_chip
# Antonyms:
# Hypernyms: snack_food.n.01
# Hyponyms:
#
#
# Word: autumn
# Synonyms: fall,autumn
# Antonyms:
# Hypernyms: season.n.02
# Hyponyms:
#
#
# Word: morning
# Synonyms: morning,morn,morning_time,forenoon
# Antonyms:
# Hypernyms: time_period.n.01
# Hyponyms:
#
#
# Word: wandered
# Synonyms: roll,wander,swan,stray,tramp,roam,cast,ramble,rove,range,drift,vagabond
# Antonyms:
# Hypernyms: travel.v.01
# Hyponyms: gallivant.v.01,maunder.v.01
#
#
# Word: deeper
# Synonyms: deep
# Antonyms: shallow
# Hypernyms:
# Hyponyms:
#
#
# Word: forest
# Synonyms: forest,wood,woods
# Antonyms:
# Hypernyms: vegetation.n.01
# Hyponyms: bosk.n.01,grove.n.01,jungle.n.03,old_growth.n.01,rain_forest.n.01,second_growth.n.01
#
#
# Word: ever
# Synonyms: ever,of_all_time
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: had
# Synonyms: have,have_got,hold
# Antonyms:
# Hypernyms:
# Hyponyms: bear.v.11,carry.v.21,keep.v.03,keep.v.07,keep.v.19,keep.v.20,monopolize.v.02,stock.v.01,sustain.v.04,wield.v.01
#
#
# Word: before
# Synonyms: earlier,before
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: stumbled
# Synonyms: stumble,falter,bumble
# Antonyms:
# Hypernyms: walk.v.01
# Hyponyms:
#
#
# Word: an
# Synonyms: Associate_in_Nursing,AN
# Antonyms:
# Hypernyms: associate_degree.n.01
# Hyponyms:
#
#
# Word: old
# Synonyms: old
# Antonyms:
# Hypernyms: past.n.01
# Hyponyms:
#
#
# Word: stone
# Synonyms: rock,stone
# Antonyms:
# Hypernyms: natural_object.n.01
# Hyponyms: achondrite.n.01,bedrock.n.01,boulder.n.01,calculus.n.01,chondrite.n.01,clastic_rock.n.01,crystal.n.03,intrusion.n.04,outcrop.n.01,pebble.n.01,petrifaction.n.02,sill.n.02,stepping_stone.n.01,tor.n.01,wall_rock.n.01,whinstone.n.01,xenolith.n.01
#
#
# Word: it
# Synonyms: information_technology,IT
# Antonyms:
# Hypernyms: engineering.n.02
# Hyponyms:
#
#
# Word: unlike
# Synonyms: unlike,dissimilar,different
# Antonyms: like
# Hypernyms:
# Hyponyms:
#
#
# Word: perfect
# Synonyms: perfective,perfective_tense,perfect,perfect_tense
# Antonyms:
# Hypernyms: tense.n.01
# Hyponyms: future_perfect.n.01,past_perfect.n.01,present_perfect.n.01
#
#
# Word: cube
# Synonyms: cube,regular_hexahedron
# Antonyms:
# Hypernyms: regular_polyhedron.n.01
# Hyponyms: quadrate.n.01,tesseract.n.01
#
#
# Word: strange
# Synonyms: strange,unusual
# Antonyms: familiar
# Hypernyms:
# Hyponyms:
#
#
# Word: symbol
# Synonyms: symbol
# Antonyms:
# Hypernyms: signal.n.01
# Hyponyms: award.n.02,crown.n.01,dollar.n.04,icon.n.01,identifier.n.01,lingam.n.01,mantle.n.01,mark.n.06,marker.n.02,monogram.n.01,nose.n.05,numeral.n.01,pound.n.12,staff.n.05,stamp.n.03,stock_symbol.n.01,symbolism.n.01,token.n.01,type.n.05,variable.n.04,written_symbol.n.01
#
#
# Word: carved
# Synonyms: carve
# Antonyms:
# Hypernyms: cut.v.01,shape.v.02
# Hyponyms: fret.v.07,hew.v.01,sculpt.v.02
#
#
# Word: side
# Synonyms: side
# Antonyms:
# Hypernyms: region.n.01
# Hyponyms: bedside.n.01,blind_side.n.01,dockside.n.01,east_side.n.01,hand.n.05,north_side.n.01,shipside.n.01,south_side.n.01,west_side.n.01
#
#
# Word: intrigued
# Synonyms: intrigue,fascinate
# Antonyms:
# Hypernyms: matter_to.v.01
# Hyponyms: grab.v.06
#
#
# Word: crouched
# Synonyms: crouch,stoop,bend,bow
# Antonyms:
# Hypernyms: bend.v.01
# Hyponyms: huddle.v.02,squinch.v.01
#
#
# Word: examine
# Synonyms: analyze,analyse,study,examine,canvass,canvas
# Antonyms:
# Hypernyms:
# Hyponyms: anatomize.v.02,assay.v.01,audit.v.01,check.v.01,compare.v.01,diagnose.v.01,diagnose.v.02,investigate.v.01,review.v.01,screen.v.02,sieve.v.02,survey.v.01,survey.v.05,trace.v.01,view.v.02
#
#
# Word: closely
# Synonyms: closely
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: seemed
# Synonyms: look,appear,seem
# Antonyms:
# Hypernyms: be.v.01
# Hyponyms: come_across.v.02,cut.v.13,feel.v.07,feel.v.12,glitter.v.01,glow.v.02,leap_out.v.01,loom.v.01,make.v.35,pass_off.v.01,rise.v.04,sound.v.01
#
#
# Word: glow
# Synonyms: freshness,glow
# Antonyms:
# Hypernyms: good_health.n.01
# Hyponyms:
#
#
# Word: faintly
# Synonyms: faintly
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: almost
# Synonyms: about,almost,most,nearly,near,nigh,virtually,well-nigh
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: alive
# Synonyms: alive,live
# Antonyms: dead
# Hypernyms:
# Hyponyms:
#
#
# Word: suddenly
# Synonyms: suddenly,all_of_a_sudden,of_a_sudden
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: low
# Synonyms: low,depression
# Antonyms:
# Hypernyms: air_mass.n.01
# Hyponyms:
#
#
# Word: rumble
# Synonyms: rumble,rumbling,grumble,grumbling
# Antonyms:
# Hypernyms: noise.n.01
# Hyponyms:
#
#
# Word: echoed
# Synonyms: repeat,echo
# Antonyms:
# Hypernyms: utter.v.02
# Hyponyms: cuckoo.v.01,parrot.v.01,recite.v.02,reecho.v.03,regurgitate.v.03
#
#
# Word: through
# Synonyms: done,through,through_with
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: tree
# Synonyms: tree
# Antonyms:
# Hypernyms: woody_plant.n.01
# Hyponyms: aalii.n.01,acacia.n.01,african_walnut.n.01,albizzia.n.01,alder.n.02,angelim.n.01,angiospermous_tree.n.01,anise_tree.n.01,arbor.n.01,aroeira_blanca.n.01,ash.n.02,australian_nettle.n.01,balata.n.02,bayberry.n.01,bean_tree.n.01,beech.n.01,birch.n.02,bitterwood_tree.n.01,black_mangrove.n.01,blackwood.n.02,bloodwood_tree.n.01,bonduc.n.02,bonsai.n.01,bottle-tree.n.01,brazilian_ironwood.n.01,brazilian_pepper_tree.n.01,brazilwood.n.02,breakax.n.01,burma_padauk.n.01,button_tree.n.01,cabbage_tree.n.03,calaba.n.01,calabash.n.02,camwood.n.01,caracolito.n.01,carib_wood.n.01,cassia.n.01,casuarina.n.01,chaulmoogra.n.01,chestnut.n.02,chinaberry.n.02,chinese_parasol_tree.n.01,christmas_bush.n.01,cinchona.n.02,clusia.n.01,cockspur.n.02,cocobolo.n.01,coffee.n.02,conacaste.n.01,coral_tree.n.01,coralwood.n.01,cork_tree.n.01,dagame.n.01,devilwood.n.01,dhak.n.01,dhawa.n.01,dipterocarp.n.01,dita.n.01,divi-divi.n.02,ebony.n.03,elm.n.01,fever_tree.n.01,fig_tree.n.01,fringe_tree.n.01,giant_chinkapin.n.01,gliricidia.n.01,granadilla_tree.n.01,guama.n.01,guinea_pepper.n.02,gum_tree.n.01,gutta-percha_tree.n.01,gutta-percha_tree.n.02,gymnospermous_tree.n.01,hackberry.n.01,hazel.n.01,hop_hornbeam.n.01,hornbeam.n.01,hydnocarpus_laurifolia.n.01,ice-cream_bean.n.01,idesia.n.01,incense_tree.n.01,indian_beech.n.01,inga.n.01,ivory_tree.n.01,jamaica_dogwood.n.01,jamaican_cherry.n.01,japanese_pagoda_tree.n.01,kentucky_coffee_tree.n.01,ketembilla.n.01,keurboom.n.01,keurboom.n.02,kingwood.n.02,kino.n.02,kowhai.n.01,lacebark.n.01,lancewood.n.02,lanseh_tree.n.01,laurelwood.n.01,lead_tree.n.01,lemonwood.n.02,lepidobotrys.n.01,linden.n.02,locust_tree.n.01,mahogany.n.02,manila_tamarind.n.01,marblewood.n.02,maria.n.02,marmalade_tree.n.01,mayeng.n.01,mescal_bean.n.01,millettia.n.01,montezuma.n.01,msasa.n.01,nakedwood.n.01,necklace_tree.n.01,neem.n.01,nitta_tree.n.01,oak.n.02,oak_chestnut.n.01,obeche.n.02,opepe.n.01,padauk.n.01,palm.n.03,palo_verde.n.01,pandanus.n.02,pepper_tree.n.01,pepper_tree.n.02,peruvian_balsam.n.01,plane_tree.n.01,pollard.n.01,poon.n.02,prickly_ash.n.01,prickly_ash.n.02,princewood.n.01,puka.n.02,quandong.n.01,quandong.n.03,quira.n.02,red_sandalwood.n.02,red_silk-cotton_tree.n.01,ribbon_tree.n.01,rose_chestnut.n.01,rosewood.n.02,sandalwood_tree.n.01,sapling.n.01,satinwood.n.03,scarlet_wisteria_tree.n.01,scrub_beefwood.n.01,shade_tree.n.01,shaving-brush_tree.n.01,shingle_tree.n.01,silver_ash.n.01,silver_tree.n.01,silver_tree.n.02,sissoo.n.01,snag.n.02,soapberry.n.01,souari.n.01,southern_beech.n.01,spanish_tamarind.n.01,tanbark_oak.n.01,teak.n.02,timber_tree.n.01,tipu.n.01,tolu_tree.n.01,tree_of_knowledge.n.01,treelet.n.01,trifoliate_orange.n.01,tulipwood_tree.n.01,turreae.n.01,wheel_tree.n.01,white_mangrove.n.01,white_mangrove.n.02,wild_fig.n.02,wild_medlar.n.01,wild_tamarind.n.02,willow.n.01,winter's_bark.n.02,yellowwood.n.02,zebrawood.n.02
#
#
# Word: ground
# Synonyms: land,dry_land,earth,ground,solid_ground,terra_firma
# Antonyms:
# Hypernyms: object.n.01
# Hyponyms: archipelago.n.01,beachfront.n.01,cape.n.01,coastal_plain.n.01,floor.n.04,foreland.n.02,forest.n.02,island.n.01,isthmus.n.01,landmass.n.01,mainland.n.01,neck.n.02,oxbow.n.01,peninsula.n.01,plain.n.01,slash.n.02,wonderland.n.01
#
#
# Word: beneath
# Synonyms: below,at_a_lower_place,to_a_lower_place,beneath
# Antonyms: above
# Hypernyms:
# Hyponyms:
#
#
# Word: foot
# Synonyms: foot,human_foot,pes
# Antonyms:
# Hypernyms: vertebrate_foot.n.01
# Hyponyms: flatfoot.n.02
#
#
# Word: began
# Synonyms: get_down,begin,get,start_out,start,set_about,set_out,commence
# Antonyms: end
# Hypernyms:
# Hyponyms: attack.v.05,auspicate.v.02,break_in.v.03,come_on.v.05,embark.v.02,fall.v.30,get_cracking.v.01,get_to.v.02,jump_off.v.01,plunge.v.04,recommence.v.02,strike_out.v.06
#
#
# Word: tremble
# Synonyms: tremble,shiver,shake
# Antonyms:
# Hypernyms: reflex.n.01
# Hyponyms:
#
#
# Word: jumped
# Synonyms: jump,leap,bound,spring
# Antonyms:
# Hypernyms: move.v.03
# Hyponyms: bounce.v.01,bounce.v.05,burst.v.04,caper.v.01,capriole.v.01,curvet.v.01,galumph.v.01,hop.v.01,hop.v.06,leapfrog.v.01,pronk.v.01,saltate.v.02,ski_jump.v.01,vault.v.01,vault.v.02
#
#
# Word: back
# Synonyms: back,dorsum
# Antonyms:
# Hypernyms: body_part.n.01
# Hyponyms:
#
#
# Word: alarm
# Synonyms: alarm,dismay,consternation
# Antonyms:
# Hypernyms: fear.n.01
# Hyponyms:
#
#
# Word: started
# Synonyms: get_down,begin,get,start_out,start,set_about,set_out,commence
# Antonyms: end
# Hypernyms:
# Hyponyms: attack.v.05,auspicate.v.02,break_in.v.03,come_on.v.05,embark.v.02,fall.v.30,get_cracking.v.01,get_to.v.02,jump_off.v.01,plunge.v.04,recommence.v.02,strike_out.v.06
#
#
# Word: rise
# Synonyms: rise
# Antonyms: fall
# Hypernyms: emergence.n.01
# Hyponyms: crime_wave.n.01,spike.n.05,wave.n.04
#
#
# Word: earth
# Synonyms: Earth,earth,world,globe
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: hovering
# Synonyms: hover,vibrate,vacillate,oscillate
# Antonyms:
# Hypernyms: hesitate.v.01
# Hyponyms: shillyshally.v.01
#
#
# Word: soft
# Synonyms: soft
# Antonyms: hard
# Hypernyms:
# Hyponyms:
#
#
# Word: light
# Synonyms: light,visible_light,visible_radiation
# Antonyms:
# Hypernyms: actinic_radiation.n.01
# Hyponyms: beam.n.04,candlelight.n.01,corona.n.04,counterglow.n.01,daylight.n.02,firelight.n.01,fluorescence.n.01,friar's_lantern.n.01,gaslight.n.01,glow.n.05,half-light.n.01,incandescence.n.01,lamplight.n.01,luminescence.n.01,meteor.n.02,moonlight.n.01,radiance.n.01,scintillation.n.01,starlight.n.01,streamer.n.01,sunlight.n.01,torchlight.n.01,twilight.n.02
#
#
# Word: emanated
# Synonyms: emanate
# Antonyms:
# Hypernyms: come.v.01
# Hyponyms: flow_out.v.01
#
#
# Word: growing
# Synonyms: growth,growing,maturation,development,ontogeny,ontogenesis
# Antonyms: nondevelopment
# Hypernyms: organic_process.n.01
# Hyponyms: amelogenesis.n.01,angiogenesis.n.01,apposition.n.02,auxesis.n.01,blossoming.n.01,cenogenesis.n.01,cohesion.n.02,cultivation.n.04,culture.n.04,cytogenesis.n.01,foliation.n.01,fructification.n.01,gametogenesis.n.01,germination.n.01,habit.n.04,infructescence.n.01,intussusception.n.02,juvenescence.n.01,life_cycle.n.02,masculinization.n.01,morphogenesis.n.01,myelinization.n.01,neurogenesis.n.01,palingenesis.n.01,proliferation.n.01,psychogenesis.n.01,psychogenesis.n.02,psychomotor_development.n.01,psychosexual_development.n.01,rooting.n.01,suppression.n.01,teething.n.01,teratogenesis.n.01,vegetation.n.02
#
#
# Word: brighter
# Synonyms: bright
# Antonyms: dull
# Hypernyms:
# Hyponyms:
#
#
# Word: enveloped
# Synonyms: envelop,enfold,enwrap,wrap,enclose
# Antonyms:
# Hypernyms: cover.v.01
# Hyponyms: bathe.v.02,benight.v.02,capsule.v.01,cocoon.v.02,engulf.v.02,sheathe.v.02,shroud.v.01,tube.v.04
#
#
# Word: entirely
# Synonyms: wholly,entirely,completely,totally,all,altogether,whole
# Antonyms: partly
# Hypernyms:
# Hyponyms:
#
#
# Word: faded
# Synonyms: fade,melt
# Antonyms:
# Hypernyms: weaken.v.02
# Hyponyms:
#
#
# Word: found
# Synonyms: found
# Antonyms:
# Hypernyms: wage.n.01
# Hyponyms:
#
#
# Word: no
# Synonyms: no
# Antonyms: yes
# Hypernyms: negative.n.01
# Hyponyms:
#
#
# Word: longer
# Synonyms: longer,thirster,yearner
# Antonyms:
# Hypernyms: person.n.01
# Hyponyms:
#
#
# Word: familiar
# Synonyms: familiar
# Antonyms:
# Hypernyms: servant.n.01
# Hyponyms:
#
#
# Word: but
# Synonyms: merely,simply,just,only,but
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: mystical
# Synonyms: mystic,mystical
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: land
# Synonyms: land
# Antonyms:
# Hypernyms: real_property.n.01
# Hyponyms: farmstead.n.01,homestead.n.01,no_man's_land.n.02
#
#
# Word: sky
# Synonyms: sky
# Antonyms:
# Hypernyms: atmosphere.n.05
# Hyponyms: blue_sky.n.01,mackerel_sky.n.01
#
#
# Word: above
# Synonyms: above
# Antonyms:
# Hypernyms: section.n.01
# Hyponyms:
#
#
# Word: deep
# Synonyms: deep
# Antonyms:
# Hypernyms: middle.n.04
# Hyponyms:
#
#
# Word: swirling
# Synonyms: twirl,swirl,twiddle,whirl
# Antonyms:
# Hypernyms: revolve.v.01
# Hyponyms:
#
#
# Word: purple
# Synonyms: purple,purpleness
# Antonyms:
# Hypernyms: chromatic_color.n.01
# Hyponyms: lavender.n.02,mauve.n.01,reddish_purple.n.01,violet.n.02
#
#
# Word: dotted
# Synonyms: dot,stud,constellate
# Antonyms:
# Hypernyms: cover.v.03
# Hyponyms:
#
#
# Word: star
# Synonyms: star
# Antonyms:
# Hypernyms: celestial_body.n.01
# Hyponyms: binary_star.n.01,fixed_star.n.01,giant_star.n.01,lodestar.n.01,multiple_star.n.01,neutron_star.n.01,nova.n.01,red_dwarf.n.01,red_giant.n.01,sun.n.04,supergiant.n.01,supernova.n.01,variable_star.n.01,white_dwarf.n.01
#
#
# Word: twinkled
# Synonyms: flash,blink,wink,twinkle,winkle
# Antonyms:
# Hypernyms: radiate.v.05
# Hyponyms: flicker.v.03
#
#
# Word: like
# Synonyms: like,the_like,the_likes_of
# Antonyms:
# Hypernyms: kind.n.01
# Hyponyms:
#
#
# Word: diamond
# Synonyms: diamond
# Antonyms:
# Hypernyms: jewel.n.01
# Hyponyms: ice.n.03
#
#
# Word: tall
# Synonyms: tall
# Antonyms:
# Hypernyms: size.n.02
# Hyponyms:
#
#
# Word: silver
# Synonyms: silver,Ag,atomic_number_47
# Antonyms:
# Hypernyms: conductor.n.02,noble_metal.n.01
# Hyponyms: coin_silver.n.01
#
#
# Word: leaf
# Synonyms: leaf,leafage,foliage
# Antonyms:
# Hypernyms: plant_organ.n.01
# Hyponyms: amplexicaul_leaf.n.01,blade.n.01,cataphyll.n.01,compound_leaf.n.01,crenate_leaf.n.01,dandelion_green.n.01,dentate_leaf.n.01,emarginate_leaf.n.01,entire_leaf.n.01,erose_leaf.n.01,fig_leaf.n.01,floral_leaf.n.01,frond.n.01,greenery.n.01,leaflet.n.02,lobed_leaf.n.01,pad.n.02,parallel-veined_leaf.n.01,parted_leaf.n.01,pitcher.n.04,prickly-edged_leaf.n.01,rosette.n.03,runcinate_leaf.n.01,scale.n.04,serrate_leaf.n.01,simple_leaf.n.01,sporophyll.n.01
#
#
# Word: breeze
# Synonyms: breeze,zephyr,gentle_wind,air
# Antonyms:
# Hypernyms: wind.n.01
# Hyponyms: breath.n.05,fresh_breeze.n.01,gentle_breeze.n.01,light_air.n.01,light_breeze.n.01,moderate_breeze.n.01,sea_breeze.n.01,strong_breeze.n.01
#
#
# Word: distance
# Synonyms: distance
# Antonyms:
# Hypernyms: spacing.n.02
# Hyponyms: elevation.n.05,farness.n.01,focal_distance.n.01,hour.n.04,hour_angle.n.01,hyperfocal_distance.n.01,interval.n.03,leap.n.04,mean_distance.n.01,mileage.n.01,nearness.n.01,piece.n.09,remove.n.01,span.n.02,wavelength.n.01,way.n.09,wheelbase.n.01,yardage.n.01
#
#
# Word: see
# Synonyms: see
# Antonyms:
# Hypernyms: seat.n.05
# Hyponyms:
#
#
# Word: grand
# Synonyms: thousand,one_thousand,1000,M,K,chiliad,G,grand,thou,yard
# Antonyms:
# Hypernyms: large_integer.n.01
# Hyponyms: millenary.n.03
#
#
# Word: castle
# Synonyms: palace,castle
# Antonyms:
# Hypernyms: mansion.n.02
# Hyponyms:
#
#
# Word: spire
# Synonyms: steeple,spire
# Antonyms:
# Hypernyms: tower.n.01
# Hyponyms: pinnacle.n.01
#
#
# Word: reaching
# Synonyms: reach,reaching,stretch
# Antonyms:
# Hypernyms: motion.n.03
# Hyponyms: outreach.n.01
#
#
# Word: up
# Synonyms: up
# Antonyms:
# Hypernyms: increase.v.02
# Hyponyms:
#
#
# Word: heaven
# Synonyms: Eden,paradise,nirvana,heaven,promised_land,Shangri-la
# Antonyms:
# Hypernyms: region.n.01
# Hyponyms:
#
#
# Word: glowing
# Synonyms: radiance,glow,glowing
# Antonyms:
# Hypernyms: light.n.01
# Hyponyms: aureole.n.01
#
#
# Word: inviting
# Synonyms: invite,ask_for
# Antonyms:
# Hypernyms: arouse.v.01
# Hyponyms:
#
#
# Word: walked
# Synonyms: walk
# Antonyms: ride
# Hypernyms: travel.v.01
# Hyponyms: amble.v.01,ambulate.v.01,clump.v.03,flounce.v.01,foot.v.02,hike.v.02,limp.v.01,lollop.v.01,lumber.v.01,march.v.01,march.v.03,mince.v.02,pace.v.01,perambulate.v.02,promenade.v.02,prowl.v.01,shuffle.v.01,skulk.v.03,sleepwalk.v.01,slink.v.01,slog.v.02,slouch.v.02,sneak.v.01,spacewalk.v.01,stagger.v.01,stagger.v.02,stalk.v.01,step.v.07,stomp.v.01,stride.v.01,stroll.v.01,stumble.v.01,tap.v.08,tiptoe.v.01,tittup.v.01,toddle.v.01,toe.v.01,traipse.v.01,tramp_down.v.01,tread.v.02,wade.v.01
#
#
# Word: noticed
# Synonyms: detect,observe,find,discover,notice
# Antonyms:
# Hypernyms: spy.v.03
# Hyponyms: find_out.v.04,instantiate.v.02,see.v.19,sense.v.02,trace.v.05
#
#
# Word: animal
# Synonyms: animal,animate_being,beast,brute,creature,fauna
# Antonyms:
# Hypernyms: organism.n.01
# Hyponyms: acrodont.n.01,adult.n.02,biped.n.01,captive.n.02,chordate.n.01,creepy-crawly.n.01,critter.n.01,darter.n.02,domestic_animal.n.01,embryo.n.02,feeder.n.06,female.n.01,fictional_animal.n.01,game.n.04,giant.n.01,herbivore.n.01,hexapod.n.01,homeotherm.n.01,insectivore.n.02,invertebrate.n.01,larva.n.01,male.n.01,marine_animal.n.01,mate.n.03,metazoan.n.01,migrator.n.02,molter.n.01,mutant.n.02,omnivore.n.02,peeper.n.03,pest.n.04,pet.n.01,pleurodont.n.01,poikilotherm.n.01,predator.n.02,prey.n.02,racer.n.03,range_animal.n.01,scavenger.n.03,stayer.n.01,stunt.n.02,survivor.n.03,thoroughbred.n.03,varmint.n.02,work_animal.n.01,young.n.01,zooplankton.n.01
#
#
# Word: any
# Synonyms: any,whatever,whatsoever
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: seen
# Synonyms: see
# Antonyms:
# Hypernyms: perceive.v.01
# Hyponyms: behold.v.01,catch_sight.v.01,glimpse.v.01,see.v.17
#
#
# Word: bird
# Synonyms: bird
# Antonyms:
# Hypernyms: vertebrate.n.01
# Hyponyms: apodiform_bird.n.01,aquatic_bird.n.01,archaeopteryx.n.01,archaeornis.n.01,bird_of_passage.n.02,bird_of_prey.n.01,caprimulgiform_bird.n.01,carinate.n.01,cock.n.05,coraciiform_bird.n.01,cuculiform_bird.n.01,dickeybird.n.01,gallinaceous_bird.n.01,hen.n.02,ibero-mesornis.n.01,nester.n.02,night_bird.n.01,nonpasserine_bird.n.01,parrot.n.01,passerine.n.01,piciform_bird.n.01,protoavis.n.01,ratite.n.01,sinornis.n.01,trogon.n.01,twitterer.n.01
#
#
# Word: feather
# Synonyms: feather,plume,plumage
# Antonyms:
# Hypernyms: animal_material.n.01,body_covering.n.01
# Hyponyms: aftershaft.n.01,bastard_wing.n.01,contour_feather.n.01,down.n.01,flight_feather.n.01,hackle.n.01,marabou.n.02,scapular.n.01
#
#
# Word: glowed
# Synonyms: glow
# Antonyms:
# Hypernyms: radiate.v.05
# Hyponyms: fluoresce.v.01,flush.v.03
#
#
# Word: firefly
# Synonyms: firefly,fire_beetle,Pyrophorus_noctiluca
# Antonyms:
# Hypernyms: elaterid_beetle.n.01
# Hyponyms:
#
#
# Word: rabbit
# Synonyms: rabbit,coney,cony
# Antonyms:
# Hypernyms: leporid.n.01
# Hyponyms: angora.n.03,belgian_hare.n.01,bunny.n.02,european_rabbit.n.01,lapin.n.02,rabbit_ears.n.02,wood_rabbit.n.01
#
#
# Word: fur
# Synonyms: fur,pelt
# Antonyms:
# Hypernyms: animal_skin.n.01
# Hyponyms: astrakhan.n.01,bearskin.n.01,beaver.n.01,chinchilla.n.01,ermine.n.01,fox.n.03,lambskin.n.01,lapin.n.01,leopard.n.01,mink.n.01,muskrat.n.01,otter.n.01,raccoon.n.01,sable.n.02,seal.n.03,squirrel.n.02
#
#
# Word: blue
# Synonyms: blue,blueness
# Antonyms:
# Hypernyms: chromatic_color.n.01
# Hyponyms: azure.n.01,dark_blue.n.01,greenish_blue.n.01,powder_blue.n.01,prussian_blue.n.02,purplish_blue.n.01,steel_blue.n.01,ultramarine.n.02
#
#
# Word: ocean
# Synonyms: ocean
# Antonyms:
# Hypernyms: body_of_water.n.01
# Hyponyms: deep.n.03
#
#
# Word: deer
# Synonyms: deer,cervid
# Antonyms:
# Hypernyms: ruminant.n.01
# Hyponyms: brocket.n.01,caribou.n.01,elk.n.01,fallow_deer.n.01,fawn.n.02,japanese_deer.n.01,mule_deer.n.01,muntjac.n.01,musk_deer.n.01,pere_david's_deer.n.01,pricket.n.02,red_deer.n.01,roe_deer.n.01,sambar.n.01,virginia_deer.n.01,wapiti.n.01
#
#
# Word: antler
# Synonyms: antler
# Antonyms:
# Hypernyms: horn.n.02
# Hyponyms:
#
#
# Word: made
# Synonyms: make,do
# Antonyms:
# Hypernyms:
# Hyponyms: overdo.v.01
#
#
# Word: crystal
# Synonyms: crystal
# Antonyms:
# Hypernyms: solid.n.01
# Hyponyms: gem.n.02,ice.n.01,ice_crystal.n.01,snowflake.n.01,twins.n.01
#
#
# Word: world
# Synonyms: universe,existence,creation,world,cosmos,macrocosm
# Antonyms:
# Hypernyms: natural_object.n.01
# Hyponyms: closed_universe.n.01,natural_order.n.01,nature.n.03
#
#
# Word: be
# Synonyms: beryllium,Be,glucinium,atomic_number_4
# Antonyms:
# Hypernyms: metallic_element.n.01
# Hyponyms:
#
#
# Word: magic
# Synonyms: magic,thaumaturgy
# Antonyms:
# Hypernyms: supernaturalism.n.01
# Hyponyms: conjuring.n.01,juju.n.01,mojo.n.01,sorcery.n.01,white_magic.n.01
#
#
# Word: finally
# Synonyms: finally,eventually
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: reached
# Synonyms: reach,make,attain,hit,arrive_at,gain
# Antonyms:
# Hypernyms:
# Hyponyms: access.v.02,bottom_out.v.01,catch_up.v.01,culminate.v.04,find.v.15,get_through.v.03,ground.v.06,make.v.37,scale.v.04,summit.v.01,top.v.06,top_out.v.03
#
#
# Word: massive
# Synonyms: massive,monolithic,monumental
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: wooden
# Synonyms: wooden
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: door
# Synonyms: door
# Antonyms:
# Hypernyms: movable_barrier.n.01
# Hyponyms: car_door.n.01,cargo_door.n.01,double_door.n.01,fire_door.n.01,french_door.n.01,interior_door.n.01,revolving_door.n.02,screen_door.n.01,sliding_door.n.01,storm_door.n.01,swing_door.n.01,trap_door.n.01
#
#
# Word: creaked
# Synonyms: whine,squeak,screech,creak,screak,skreak
# Antonyms:
# Hypernyms: make_noise.v.01
# Hyponyms:
#
#
# Word: open
# Synonyms: open,clear
# Antonyms:
# Hypernyms: area.n.01
# Hyponyms:
#
#
# Word: expecting
# Synonyms: expect,anticipate
# Antonyms:
# Hypernyms: evaluate.v.02
# Hyponyms: assume.v.01,believe.v.03,speculate.v.01,think.v.02
#
#
# Word: inside
# Synonyms: inside,interior
# Antonyms: outside
# Hypernyms: region.n.01
# Hyponyms: midland.n.02,midst.n.01,penetralia.n.01
#
#
# Word: wall
# Synonyms: wall
# Antonyms:
# Hypernyms: partition.n.01
# Hyponyms: attic.n.04,bearing_wall.n.01,cavity_wall.n.01,chimney_breast.n.01,firewall.n.03,gable.n.01,parapet.n.01,proscenium.n.02,sidewall.n.02,wainscoting.n.01
#
#
# Word: lined
# Synonyms: line,run_along
# Antonyms:
# Hypernyms: lie.v.01
# Hyponyms: rim.v.01
#
#
# Word: tapestry
# Synonyms: tapestry
# Antonyms:
# Hypernyms: complexity.n.01
# Hyponyms:
#
#
# Word: depicting
# Synonyms: depicting,depiction,portraying,portrayal
# Antonyms:
# Hypernyms: representational_process.n.01
# Hyponyms: mirror.n.02
#
#
# Word: epic
# Synonyms: epic_poem,heroic_poem,epic,epos
# Antonyms:
# Hypernyms: poem.n.01
# Hyponyms: chanson_de_geste.n.01,heroic_verse.n.01,rhapsody.n.01
#
#
# Word: battle
# Synonyms: battle,conflict,fight,engagement
# Antonyms:
# Hypernyms: military_action.n.01
# Hyponyms: armageddon.n.02,assault.n.01,combat.n.01,dogfight.n.03,naval_battle.n.01,pitched_battle.n.01
#
#
# Word: beautiful
# Synonyms: beautiful
# Antonyms: ugly
# Hypernyms:
# Hyponyms:
#
#
# Word: landscape
# Synonyms: landscape
# Antonyms:
# Hypernyms: scenery.n.02
# Hyponyms:
#
#
# Word: tale
# Synonyms: narrative,narration,story,tale
# Antonyms:
# Hypernyms: message.n.02
# Hyponyms: fairytale.n.01,folktale.n.01,nursery_rhyme.n.01,sob_story.n.01,tall_tale.n.01,tearjerker.n.01
#
#
# Word: at
# Synonyms: astatine,At,atomic_number_85
# Antonyms:
# Hypernyms: chemical_element.n.01,halogen.n.01
# Hyponyms:
#
#
# Word: end
# Synonyms: end,terminal
# Antonyms:
# Hypernyms: extremity.n.04
# Hyponyms: bitter_end.n.02,bitthead.n.01,end_point.n.01,finish.n.04,heel.n.04,heel.n.05,nerve_ending.n.01,point.n.15,pole.n.10,railhead.n.02,telomere.n.01,terminus.n.04,tip.n.01,yardarm.n.01
#
#
# Word: hall
# Synonyms: hallway,hall
# Antonyms:
# Hypernyms: corridor.n.01
# Hyponyms: concourse.n.02
#
#
# Word: stood
# Synonyms: stand,stand_up
# Antonyms: sit,lie
# Hypernyms: rest.v.01
# Hyponyms: line_up.v.03,ramp.v.05,stand_back.v.02
#
#
# Word: regal
# Synonyms: imperial,majestic,purple,regal,royal
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: woman
# Synonyms: woman,adult_female
# Antonyms: man
# Hypernyms: adult.n.01,female.n.02
# Hyponyms: amazon.n.01,b-girl.n.01,bachelor_girl.n.01,baggage.n.02,ball-buster.n.01,black_woman.n.01,bluestocking.n.01,bridesmaid.n.01,broad.n.01,cat.n.03,cinderella.n.01,coquette.n.01,dame.n.02,debutante.n.01,divorcee.n.01,dominatrix.n.01,donna.n.01,enchantress.n.01,ex-wife.n.01,eyeful.n.01,geisha.n.01,girl.n.01,girl.n.05,girlfriend.n.01,girlfriend.n.02,gold_digger.n.02,gravida.n.02,heroine.n.02,inamorata.n.01,jezebel.n.02,jilt.n.01,lady.n.01,maenad.n.01,maenad.n.02,matriarch.n.01,matriarch.n.02,matron.n.03,mestiza.n.01,mistress.n.01,mother_figure.n.01,nanny.n.01,nullipara.n.01,nymph.n.03,nymphet.n.01,old_woman.n.01,prostitute.n.01,shiksa.n.01,smasher.n.02,sylph.n.01,unmarried_woman.n.01,vestal.n.01,wac.n.01,wave.n.09,white_woman.n.01,widow.n.01,wife.n.01,wonder_woman.n.01,yellow_woman.n.01
#
#
# Word: long
# Synonyms: hanker,long,yearn
# Antonyms:
# Hypernyms: desire.v.01
# Hyponyms: ache.v.02
#
#
# Word: hair
# Synonyms: hair
# Antonyms:
# Hypernyms: body_covering.n.01
# Hyponyms: beard.n.04,body_hair.n.01,coat.n.03,cowlick.n.01,down.n.05,eyebrow.n.01,eyelash.n.01,facial_hair.n.01,forelock.n.02,guard_hair.n.01,hairdo.n.01,lock.n.02,mane.n.01,mane.n.02,pubic_hair.n.01
#
#
# Word: flowing
# Synonyms: flow,flowing
# Antonyms:
# Hypernyms: change_of_location.n.01
# Hyponyms: airflow.n.01,backflow.n.01,current.n.02,discharge.n.06,drip.n.01,dripping.n.01,ebb.n.02,emission.n.05,flush.n.06,flux.n.02,fountain.n.03,freshet.n.01,overflow.n.02,rush.n.02,seepage.n.01
#
#
# Word: liquid
# Synonyms: liquid
# Antonyms:
# Hypernyms: fluid.n.01
# Hyponyms: alcohol.n.02,ammonia_water.n.01,antifreeze.n.01,beverage.n.01,distillate.n.01,grume.n.01,ink.n.01,liquor.n.02,medium.n.05,pyroligneous_acid.n.01,sheep_dip.n.01,snake_oil.n.01,supernatant.n.01,water.n.06
#
#
# Word: eye
# Synonyms: eye,oculus,optic
# Antonyms:
# Hypernyms: sense_organ.n.01
# Hyponyms: compound_eye.n.01,naked_eye.n.01,oculus_dexter.n.01,oculus_sinister.n.01,peeper.n.02,simple_eye.n.01
#
#
# Word: wisdom
# Synonyms: wisdom
# Antonyms:
# Hypernyms: content.n.05
# Hyponyms: reconditeness.n.01
#
#
# Word: welcome
# Synonyms: welcome
# Antonyms:
# Hypernyms: acceptance.n.03
# Hyponyms:
#
#
# Word: said
# Synonyms: state,say,tell
# Antonyms:
# Hypernyms: express.v.02
# Hyponyms: add.v.02,announce.v.02,answer.v.01,articulate.v.05,declare.v.01,declare.v.07,explain.v.02,get_out.v.04,give.v.04,misstate.v.01,note.v.01,precede.v.05,present.v.02,summarize.v.02
#
#
# Word: voice
# Synonyms: voice
# Antonyms:
# Hypernyms: sound.n.01
# Hyponyms: androglossia.n.01
#
#
# Word: echoing
# Synonyms: repeat,echo
# Antonyms:
# Hypernyms: utter.v.02
# Hyponyms: cuckoo.v.01,parrot.v.01,recite.v.02,reecho.v.03,regurgitate.v.03
#
#
# Word: softly
# Synonyms: softly,quietly
# Antonyms: loudly
# Hypernyms:
# Hyponyms:
#
#
# Word: i
# Synonyms: iodine,iodin,I,atomic_number_53
# Antonyms:
# Hypernyms: chemical_element.n.01,halogen.n.01
# Hyponyms: iodine-125.n.01,iodine-131.n.01
#
#
# Word: am
# Synonyms: americium,Am,atomic_number_95
# Antonyms:
# Hypernyms: metallic_element.n.01
# Hyponyms:
#
#
# Word: queen
# Synonyms: queen
# Antonyms:
# Hypernyms: insect.n.01
# Hyponyms: queen_bee.n.01
#
#
# Word: ruler
# Synonyms: ruler,swayer
# Antonyms:
# Hypernyms: person.n.01
# Hyponyms: basileus.n.01,bourbon.n.03,caliph.n.01,dictator.n.02,dynast.n.01,emir.n.01,ethnarch.n.01,hakim.n.01,hanoverian.n.01,inca.n.01,khan.n.01,mogul.n.02,oligarch.n.01,overlord.n.01,pharaoh.n.01,puppet_ruler.n.01,regent.n.02,sheik.n.01,sovereign.n.01,stuart.n.02,sultan.n.01,tudor.n.03,tyrant.n.02
#
#
# Word: realm
# Synonyms: kingdom,land,realm
# Antonyms:
# Hypernyms: sphere.n.01
# Hyponyms: lotusland.n.01
#
#
# Word: have
# Synonyms: rich_person,wealthy_person,have
# Antonyms:
# Hypernyms: person.n.01
# Hyponyms: affluent.n.01,billionaire.n.01,croesus.n.02,fat_cat.n.01,man_of_means.n.01,millionaire.n.01,millionairess.n.01,multi-billionaire.n.01,plutocrat.n.01
#
#
# Word: been
# Synonyms: be
# Antonyms:
# Hypernyms:
# Hyponyms: abound.v.01,accept.v.08,account.v.01,account_for.v.01,act.v.06,answer.v.06,appear.v.04,bake.v.04,balance.v.04,be_well.v.01,beat.v.12,begin.v.06,begin.v.07,belong.v.01,belong.v.02,belong.v.04,belong.v.05,breathe.v.04,buy.v.03,clean.v.05,cohere.v.03,come_in_for.v.01,come_in_handy.v.01,compact.v.01,compare.v.02,confuse.v.02,connect.v.07,consist.v.02,consist.v.04,contain.v.04,contain.v.05,continue.v.10,cost.v.01,count.v.02,count.v.07,cover.v.18,cut.v.25,cut_across.v.02,deck.v.01,depend.v.01,deserve.v.01,disagree.v.02,distribute.v.09,diverge.v.02,draw.v.21,end.v.03,fall.v.04,fall.v.16,feel.v.04,figure.v.02,fit.v.07,gape.v.02,go.v.10,gravitate.v.02,hail.v.02,hang.v.06,head.v.04,hold.v.17,hoodoo.v.01,hum.v.02,impend.v.01,incarnate.v.02,iridesce.v.01,jumble.v.01,kill.v.04,lend.v.03,let_go.v.02,lie.v.04,litter.v.01,loiter.v.01,look.v.02,look.v.03,lubricate.v.01,make.v.31,make_sense.v.01,measure.v.03,mope.v.02,object.v.02,osculate.v.01,owe.v.03,pay.v.07,point.v.10,press.v.08,promise.v.04,prove.v.01,put_out.v.06,rage.v.02,range.v.01,rank.v.01,rate.v.02,recognize.v.08,relate.v.04,remain.v.03,represent.v.03,rest.v.01,retard.v.02,run.v.05,run_into.v.01,rut.v.01,seem.v.03,seethe.v.02,sell.v.02,sell.v.06,sell.v.07,shine.v.04,shine.v.05,sparkle.v.02,specify.v.03,squat.v.02,stagnate.v.01,stagnate.v.03,stand.v.02,stand.v.03,stand_by.v.03,stay.v.01,stay.v.04,stick.v.04,stink.v.01,subtend.v.01,suck.v.04,suffer.v.06,suffer.v.08,suit.v.02,swim.v.03,swim.v.04,swing.v.10,tend.v.01,test.v.04,total.v.01,translate.v.07,transplant.v.02,trim.v.05,underlie.v.01,want.v.02,wash.v.05,wind.v.02,work.v.14
#
#
# Word: chosen
# Synonyms: chosen
# Antonyms:
# Hypernyms: darling.n.01
# Hyponyms:
#
#
# Word: by
# Synonyms: by,past
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: ancient
# Synonyms: ancient,antediluvian
# Antonyms:
# Hypernyms: oldster.n.01
# Hyponyms:
#
#
# Word: embark
# Synonyms: embark,ship
# Antonyms: disembark
# Hypernyms: board.v.01
# Hyponyms: emplane.v.01
#
#
# Word: on
# Synonyms: on
# Antonyms: off
# Hypernyms:
# Hyponyms:
#
#
# Word: quest
# Synonyms: pursuit,pursuance,quest
# Antonyms:
# Hypernyms: search.n.04
# Hyponyms: wild-goose_chase.n.01
#
#
# Word: great
# Synonyms: great
# Antonyms:
# Hypernyms: achiever.n.01
# Hyponyms:
#
#
# Word: taken
# Synonyms: take
# Antonyms:
# Hypernyms: act.v.01
# Hyponyms:
#
#
# Word: aback
# Synonyms: aback
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: why
# Synonyms: why,wherefore
# Antonyms:
# Hypernyms: reason.n.01
# Hyponyms:
#
#
# Word: me
# Synonyms: Maine,Pine_Tree_State,ME
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: smiled
# Synonyms: smile
# Antonyms:
# Hypernyms: grimace.v.01
# Hyponyms: beam.v.01,dimple.v.02,grin.v.01,smirk.v.01,sneer.v.02
#
#
# Word: gently
# Synonyms: gently
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: posse
# Synonyms: posse,posse_comitatus
# Antonyms:
# Hypernyms: police.n.01
# Hyponyms:
#
#
# Word: heart
# Synonyms: heart,bosom
# Antonyms:
# Hypernyms: intuition.n.02
# Hyponyms:
#
#
# Word: true
# Synonyms: true
# Antonyms:
# Hypernyms: alignment.n.02
# Hyponyms:
#
#
# Word: adventurer
# Synonyms: adventurer,venturer
# Antonyms:
# Hypernyms: person.n.01
# Hyponyms: adventuress.n.01,argonaut.n.01,cowboy.n.03,daredevil.n.01,gambler.n.02,hotspur.n.02,mercenary.n.01,mountaineer.n.01,speculator.n.02
#
#
# Word: courage
# Synonyms: courage,courageousness,bravery,braveness
# Antonyms: cowardice
# Hypernyms: spirit.n.03
# Hyponyms: dauntlessness.n.01,dutch_courage.n.01,fearlessness.n.02,fortitude.n.01,heart.n.03,heroism.n.01,stoutheartedness.n.01
#
#
# Word: face
# Synonyms: face,human_face
# Antonyms:
# Hypernyms: external_body_part.n.01
# Hyponyms: countenance.n.03
#
#
# Word: unknown
# Synonyms: unknown,unknown_region,terra_incognita
# Antonyms:
# Hypernyms: region.n.03
# Hyponyms:
#
#
# Word: is
# Synonyms: be
# Antonyms:
# Hypernyms:
# Hyponyms: abound.v.01,accept.v.08,account.v.01,account_for.v.01,act.v.06,answer.v.06,appear.v.04,bake.v.04,balance.v.04,be_well.v.01,beat.v.12,begin.v.06,begin.v.07,belong.v.01,belong.v.02,belong.v.04,belong.v.05,breathe.v.04,buy.v.03,clean.v.05,cohere.v.03,come_in_for.v.01,come_in_handy.v.01,compact.v.01,compare.v.02,confuse.v.02,connect.v.07,consist.v.02,consist.v.04,contain.v.04,contain.v.05,continue.v.10,cost.v.01,count.v.02,count.v.07,cover.v.18,cut.v.25,cut_across.v.02,deck.v.01,depend.v.01,deserve.v.01,disagree.v.02,distribute.v.09,diverge.v.02,draw.v.21,end.v.03,fall.v.04,fall.v.16,feel.v.04,figure.v.02,fit.v.07,gape.v.02,go.v.10,gravitate.v.02,hail.v.02,hang.v.06,head.v.04,hold.v.17,hoodoo.v.01,hum.v.02,impend.v.01,incarnate.v.02,iridesce.v.01,jumble.v.01,kill.v.04,lend.v.03,let_go.v.02,lie.v.04,litter.v.01,loiter.v.01,look.v.02,look.v.03,lubricate.v.01,make.v.31,make_sense.v.01,measure.v.03,mope.v.02,object.v.02,osculate.v.01,owe.v.03,pay.v.07,point.v.10,press.v.08,promise.v.04,prove.v.01,put_out.v.06,rage.v.02,range.v.01,rank.v.01,rate.v.02,recognize.v.08,relate.v.04,remain.v.03,represent.v.03,rest.v.01,retard.v.02,run.v.05,run_into.v.01,rut.v.01,seem.v.03,seethe.v.02,sell.v.02,sell.v.06,sell.v.07,shine.v.04,shine.v.05,sparkle.v.02,specify.v.03,squat.v.02,stagnate.v.01,stagnate.v.03,stand.v.02,stand.v.03,stand_by.v.03,stay.v.01,stay.v.04,stick.v.04,stink.v.01,subtend.v.01,suck.v.04,suffer.v.06,suffer.v.08,suit.v.02,swim.v.03,swim.v.04,swing.v.10,tend.v.01,test.v.04,total.v.01,translate.v.07,transplant.v.02,trim.v.05,underlie.v.01,want.v.02,wash.v.05,wind.v.02,work.v.14
#
#
# Word: danger
# Synonyms: danger
# Antonyms: safety
# Hypernyms: condition.n.01
# Hyponyms: clear_and_present_danger.n.01,hazardousness.n.01,insecurity.n.01,riskiness.n.01,vulnerability.n.01
#
#
# Word: only
# Synonyms: lone,lonesome,only,sole,solitary
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: someone
# Synonyms: person,individual,someone,somebody,mortal,soul
# Antonyms:
# Hypernyms: causal_agent.n.01,organism.n.01
# Hyponyms: abator.n.01,abjurer.n.01,abomination.n.01,abstainer.n.02,achiever.n.01,acquaintance.n.03,acquirer.n.01,active.n.03,actor.n.02,adjudicator.n.01,admirer.n.02,adoptee.n.01,adult.n.01,adventurer.n.01,adversary.n.01,advisee.n.01,advocate.n.01,affiant.n.01,african.n.01,agnostic.n.01,amateur.n.01,amerindian.n.01,ancient.n.02,anomaly.n.02,anti-american.n.01,anti.n.01,applicant.n.01,appointee.n.02,appreciator.n.01,apprehender.n.02,aquarius.n.01,archaist.n.01,aries.n.01,arrogator.n.01,assessee.n.01,asthmatic.n.01,authority.n.02,autodidact.n.01,baby_boomer.n.01,baby_buster.n.01,bad_guy.n.01,bad_person.n.01,baldhead.n.01,balker.n.01,bather.n.02,beard.n.03,bedfellow.n.02,bereaved.n.01,best.n.02,birth.n.05,biter.n.01,black.n.05,blogger.n.01,blond.n.01,bluecoat.n.01,bodybuilder.n.01,bomber.n.02,brunet.n.01,bullfighter.n.01,buster.n.04,cancer.n.02,candidate.n.02,capitalist.n.02,capricorn.n.01,captor.n.01,case.n.06,cashier.n.02,celebrant.n.01,censor.n.01,chameleon.n.01,changer.n.01,charmer.n.02,child.n.03,chutzpanik.n.01,closer.n.01,clumsy_person.n.01,collector.n.01,color-blind_person.n.01,combatant.n.01,commoner.n.01,communicator.n.01,complexifier.n.01,compulsive.n.01,computer_user.n.01,contemplative.n.01,contestant.n.01,convert.n.01,copycat.n.01,counter.n.05,counterterrorist.n.01,coward.n.01,crawler.n.02,creator.n.02,creature.n.02,creditor.n.01,cripple.n.01,dancer.n.02,dead_person.n.01,deaf_person.n.01,debaser.n.01,debtor.n.01,defecator.n.01,delayer.n.01,deliverer.n.04,demander.n.01,dieter.n.01,differentiator.n.01,disentangler.n.01,disputant.n.01,dissenter.n.01,divider.n.02,domestic_partner.n.01,double.n.03,dresser.n.02,dribbler.n.02,drug_user.n.01,dyslectic.n.01,ectomorph.n.01,effecter.n.01,elizabethan.n.01,emotional_person.n.01,endomorph.n.01,engineer.n.01,enjoyer.n.01,enrollee.n.01,entertainer.n.01,ethnic.n.01,experimenter.n.02,expert.n.01,explorer.n.01,extrovert.n.01,face.n.05,faddist.n.01,faller.n.02,fastener.n.01,female.n.02,fiduciary.n.01,first-rater.n.01,follower.n.01,free_agent.n.02,friend.n.01,fugitive.n.01,gainer.n.01,gainer.n.02,gambler.n.01,gatekeeper.n.01,gatherer.n.01,gemini.n.01,gentile.n.02,good_guy.n.01,good_person.n.01,granter.n.01,greeter.n.01,grinner.n.01,groaner.n.01,grunter.n.01,guesser.n.01,handicapped_person.n.01,hater.n.01,heterosexual.n.01,homosexual.n.01,homunculus.n.02,hope.n.04,hoper.n.01,huddler.n.02,hugger.n.01,immune.n.01,individualist.n.01,inhabitant.n.01,innocent.n.01,insured.n.01,intellectual.n.01,interpreter.n.02,introvert.n.01,jat.n.01,jew.n.01,jewel.n.02,jumper.n.01,junior.n.03,juvenile.n.01,killer.n.01,kink.n.03,kneeler.n.01,knocker.n.02,knower.n.01,large_person.n.01,latin.n.03,laugher.n.01,leader.n.01,learner.n.01,left-hander.n.02,leo.n.01,libra.n.01,life.n.08,lightning_rod.n.01,linguist.n.02,literate.n.01,liver.n.03,longer.n.01,loose_cannon.n.01,loved_one.n.01,lover.n.01,machine.n.02,mailer.n.02,malcontent.n.01,male.n.02,man.n.03,man_jack.n.01,manipulator.n.02,married.n.01,masturbator.n.01,measurer.n.01,mesomorph.n.01,mestizo.n.01,middlebrow.n.01,miracle_man.n.01,misogamist.n.01,mixed-blood.n.01,modern.n.01,money_handler.n.01,monolingual.n.01,mother_hen.n.01,mouse.n.03,mutilator.n.01,namer.n.01,namesake.n.01,national.n.01,native.n.01,native.n.02,neglecter.n.01,neighbor.n.01,neutral.n.01,nondescript.n.01,nonmember.n.01,nonparticipant.n.01,nonpartisan.n.01,nonperson.n.01,nonreligious_person.n.01,nonresident.n.01,nonsmoker.n.01,nonworker.n.01,nude.n.03,nurser.n.01,occultist.n.01,optimist.n.01,orphan.n.02,ostrich.n.01,ouster.n.01,outcaste.n.01,outdoorsman.n.01,owner.n.02,pamperer.n.01,pansexual.n.01,pardoner.n.01,partner.n.03,party.n.05,passer.n.02,peer.n.01,perceiver.n.01,percher.n.01,person_of_color.n.01,personage.n.01,personification.n.01,perspirer.n.01,philosopher.n.02,picker.n.01,pisces.n.02,pisser.n.01,planner.n.01,player.n.04,posturer.n.01,powderer.n.01,precursor.n.02,preserver.n.03,primitive.n.01,propositus.n.01,public_relations_person.n.01,pursuer.n.02,pussycat.n.01,quarter.n.11,quitte ...
#
#
# Word: can
# Synonyms: can,tin,tin_can
# Antonyms:
# Hypernyms: container.n.01
# Hyponyms: beer_can.n.01,caddy.n.01,cannikin.n.02,coffee_can.n.01,milk_can.n.01,oilcan.n.01,soda_can.n.01
#
#
# Word: restore
# Synonyms: restore,reconstruct
# Antonyms:
# Hypernyms: regenerate.v.01
# Hyponyms: decompress.v.01,defibrillate.v.01,rehabilitate.v.01,rehabilitate.v.03,reinstate.v.01
#
#
# Word: s
# Synonyms: second,sec,s
# Antonyms:
# Hypernyms: time_unit.n.01
# Hyponyms: leap_second.n.01
#
#
# Word: pounded
# Synonyms: thump,pound,poke
# Antonyms:
# Hypernyms: hit.v.03
# Hyponyms:
#
#
# Word: excitement
# Synonyms: exhilaration,excitement
# Antonyms:
# Hypernyms: joy.n.01
# Hyponyms: bang.n.04,intoxication.n.03,titillation.n.01
#
#
# Word: fear
# Synonyms: fear,fearfulness,fright
# Antonyms: fearlessness
# Hypernyms: emotion.n.01
# Hyponyms: alarm.n.01,apprehension.n.01,creeps.n.02,frisson.n.01,horror.n.01,hysteria.n.02,intimidation.n.03,panic.n.01,scare.n.02,stage_fright.n.01,timidity.n.01
#
#
# Word: always
# Synonyms: always,ever,e'er
# Antonyms: never
# Hypernyms:
# Hyponyms:
#
#
# Word: dreamed
# Synonyms: dream,daydream,woolgather,stargaze
# Antonyms:
# Hypernyms: imagine.v.01
# Hyponyms:
#
#
# Word: going
# Synonyms: departure,going,going_away,leaving
# Antonyms:
# Hypernyms: act.n.02
# Hyponyms: boarding.n.01,breaking_away.n.02,disappearance.n.01,dispatch.n.02,exit.n.03,farewell.n.02,french_leave.n.01,sailing.n.03,takeoff.n.01,withdrawal.n.03
#
#
# Word: adventure
# Synonyms: adventure,escapade,risky_venture,dangerous_undertaking
# Antonyms:
# Hypernyms: undertaking.n.01
# Hyponyms:
#
#
# Word: beyond
# Synonyms: beyond
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: imagined
# Synonyms: imagine,conceive_of,ideate,envisage
# Antonyms:
# Hypernyms: create_by_mental_act.v.01
# ...
# Antonyms: change
# Hypernyms: be.v.01
# Hyponyms: be.v.12,keep.v.12,keep_out.v.02,sit_tight.v.01,stand.v.07,stick_together.v.01
#
#
# Word: focused
# Synonyms: concentrate,focus,center,centre,pore,rivet
# Antonyms:
# Hypernyms: think.v.03
# Hyponyms: listen.v.02,recall.v.05,steep.v.01,think.v.06,zoom_in.v.01
#
#
# Word: goal
# Synonyms: goal,end
# Antonyms:
# Hypernyms: content.n.05
# Hyponyms: aim.n.02,bourn.n.02,destination.n.02,end-all.n.01,intention.n.02,no-goal.n.01,purpose.n.01
#
#
# Word: went
# Synonyms: travel,go,move,locomote
# Antonyms: stay_in_place
# Hypernyms:
# Hyponyms: accompany.v.02,advance.v.01,angle.v.01,ascend.v.01,automobile.v.01,back.v.02,bang.v.04,beetle.v.02,betake_oneself.v.01,billow.v.02,bounce.v.03,breeze.v.02,caravan.v.01,career.v.01,carry.v.36,circle.v.01,circle.v.02,circuit.v.01,circulate.v.07,come.v.01,come.v.11,crawl.v.01,cruise.v.02,derail.v.02,descend.v.01,do.v.13,drag.v.04,draw.v.12,drive.v.02,drive.v.14,ease.v.01,fall.v.01,fall.v.15,ferry.v.03,float.v.01,float.v.02,float.v.05,flock.v.01,fly.v.01,fly.v.06,follow.v.01,follow.v.04,forge.v.05,get_around.v.04,ghost.v.01,glide.v.01,go_around.v.02,hiss.v.02,hurtle.v.01,island_hop.v.01,lance.v.01,lurch.v.03,outflank.v.01,pace.v.02,pan.v.01,pass.v.01,pass_over.v.04,play.v.09,plow.v.03,prance.v.02,precede.v.04,precess.v.01,proceed.v.02,propagate.v.02,pursue.v.02,push.v.09,raft.v.02,repair.v.03,retreat.v.02,retrograde.v.02,return.v.01,ride.v.01,ride.v.04,ride.v.10,rise.v.01,roll.v.12,round.v.01,run.v.11,run.v.34,rush.v.01,scramble.v.01,seek.v.04,shuttle.v.01,sift.v.01,ski.v.01,slice_into.v.01,slither.v.01,snowshoe.v.01,speed.v.04,steamer.v.01,step.v.01,step.v.02,step.v.06,stray.v.02,swap.v.02,swash.v.01,swim.v.01,swim.v.05,swing.v.03,taxi.v.01,trail.v.03,tram.v.01,transfer.v.06,travel.v.04,travel.v.05,travel.v.06,travel_by.v.01,travel_purposefully.v.01,travel_rapidly.v.01,trundle.v.01,turn.v.06,walk.v.01,walk.v.10,weave.v.04,wend.v.01,wheel.v.03,whine.v.01,whish.v.02,whisk.v.02,whistle.v.02,withdraw.v.01,zigzag.v.01,zoom.v.02
#
#
# Word: clearing
# Synonyms: clearing,glade
# Antonyms:
# Hypernyms: tract.n.01
# Hyponyms:
#
#
# Word: trunk
# Synonyms: trunk,tree_trunk,bole
# Antonyms:
# Hypernyms: stalk.n.02
# Hyponyms:
#
#
# Word: blackened
# Synonyms: blacken,melanize,melanise,nigrify,black
# Antonyms: whiten
# Hypernyms: discolor.v.03
# Hyponyms:
#
#
# Word: base
# Synonyms: base,base_of_operations
# Antonyms:
# Hypernyms: military_installation.n.01
# Hyponyms: air_base.n.01,army_base.n.01,firebase.n.01,navy_base.n.01,rocket_base.n.01
#
#
# Word: lay
# Synonyms: ballad,lay
# Antonyms:
# Hypernyms: song.n.01
# Hyponyms: minstrelsy.n.02
#
#
# Word: pulsing
# Synonyms: pulsation,pulsing,pulse,impulse
# Antonyms:
# Hypernyms: wave.n.03
# Hyponyms:
#
#
# Word: approached
# Synonyms: approach,near,come_on,go_up,draw_near,draw_close,come_near
# Antonyms:
# Hypernyms: come.v.01
# Hyponyms: bear_down_on.v.01,close.v.12,drive_up.v.01,edge_in.v.01,push.v.06
#
#
# Word: shadowy
# Synonyms: shady,shadowed,shadowy,umbrageous
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: figure
# Synonyms: figure,fig
# Antonyms:
# Hypernyms: illustration.n.01
# Hyponyms:
#
#
# Word: emerged
# Synonyms: emerge
# Antonyms:
# Hypernyms: appear.v.02
# Hyponyms: burst.v.06,shell.v.03
#
#
# Word: fearsome
# Synonyms: awful,dire,direful,dread,dreaded,dreadful,fearful,fearsome,frightening,horrendous,horrific,terrible
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: red
# Synonyms: red,redness
# Antonyms:
# Hypernyms: chromatic_color.n.01
# Hyponyms: cardinal.n.03,cerise.n.01,chrome_red.n.01,crimson.n.01,dark_red.n.01,purplish_red.n.01,sanguine.n.01,scarlet.n.01,turkey_red.n.01
#
#
# Word: claw
# Synonyms: claw
# Antonyms:
# Hypernyms: horny_structure.n.01
# Hyponyms: bear_claw.n.03,talon.n.01
#
#
# Word: sharp
# Synonyms: sharp
# Antonyms:
# Hypernyms: musical_notation.n.01
# Hyponyms: double_sharp.n.01
#
#
# Word: dagger
# Synonyms: dagger,sticker
# Antonyms:
# Hypernyms: knife.n.02
# Hyponyms: dirk.n.01,kirpan.n.01,kris.n.01,poniard.n.01,stiletto.n.01
#
#
# Word: hissed
# Synonyms: hiss,siss,sizz,sibilate
# Antonyms:
# Hypernyms: utter.v.02
# Hyponyms:
#
#
# Word: dripping
# Synonyms: dripping,drippage
# Antonyms:
# Hypernyms: flow.n.01
# Hyponyms:
#
#
# Word: malice
# Synonyms: malice,maliciousness,spite,spitefulness,venom
# Antonyms:
# Hypernyms: malevolence.n.01
# Hyponyms:
#
#
# Word: consume
# Synonyms: devour,down,consume,go_through
# Antonyms:
# Hypernyms: eat.v.01
# Hyponyms:
#
#
# Word: fueled
# Synonyms: fuel
# Antonyms:
# Hypernyms: supply.v.01
# Hyponyms: bunker.v.02,gas_up.v.01,refuel.v.01
#
#
# Word: spoken
# Synonyms: talk,speak,utter,mouth,verbalize,verbalise
# Antonyms:
# Hypernyms: communicate.v.02
# Hyponyms: babble.v.01,bark.v.01,bay.v.01,begin.v.04,blubber.v.02,blurt_out.v.01,bumble.v.03,cackle.v.01,chatter.v.04,chatter.v.05,deliver.v.01,drone.v.02,enthuse.v.02,generalize.v.02,gulp.v.02,hiss.v.03,lip_off.v.01,mumble.v.01,murmur.v.01,open_up.v.07,peep.v.04,rant.v.01,rasp.v.02,read.v.03,shout.v.01,sing.v.02,slur.v.03,snap.v.01,snivel.v.01,speak_in_tongues.v.01,speak_up.v.02,swallow.v.04,talk_of.v.01,tone.v.01,tone.v.02,troll.v.07,verbalize.v.01,vocalize.v.05,whiff.v.05,whisper.v.01,yack.v.01
#
#
# Word: held
# Synonyms: keep,maintain,hold
# Antonyms:
# Hypernyms:
# Hyponyms: conserve.v.01,continue.v.03,distance.v.01,hold_over.v.03,housekeep.v.01,preserve.v.06,pressurize.v.02
#
#
# Word: high
# Synonyms: high
# Antonyms: low
# Hypernyms: degree.n.01
# Hyponyms:
#
#
# Word: blinding
# Synonyms: blind
# Antonyms:
# Hypernyms:
# Hyponyms: dazzle.v.01,seel.v.01,snow-blind.v.01
#
#
# Word: recoiled
# Synonyms: flinch,squinch,funk,cringe,shrink,wince,recoil,quail
# Antonyms:
# Hypernyms: move.v.03
# Hyponyms: shrink_back.v.01
#
#
# Word: screeching
# Synonyms: screech,screeching,shriek,shrieking,scream,screaming
# Antonyms:
# Hypernyms: noise.n.01
# Hyponyms:
#
#
# Word: pain
# Synonyms: pain,hurting
# Antonyms:
# Hypernyms: symptom.n.01
# Hyponyms: ache.n.01,agony.n.02,arthralgia.n.01,burn.n.01,causalgia.n.01,chest_pain.n.01,chiralgia.n.01,colic.n.01,distress.n.03,dysmenorrhea.n.01,glossalgia.n.01,growing_pains.n.01,hemorrhoid.n.01,keratalgia.n.01,labor_pain.n.01,mastalgia.n.01,melagra.n.01,meralgia.n.01,metralgia.n.01,myalgia.n.01,nephralgia.n.01,neuralgia.n.01,odynophagia.n.01,orchidalgia.n.01,pang.n.02,pang.n.03,photalgia.n.01,pleurodynia.n.01,podalgia.n.01,proctalgia.n.01,referred_pain.n.01,renal_colic.n.01,smart.n.01,sting.n.01,stitch.n.02,tenderness.n.02,thermalgesia.n.01,throb.n.01,torture.n.02,ulalgia.n.01,urodynia.n.01
#
#
# Word: final
# Synonyms: final
# Antonyms:
# Hypernyms: match.n.02
# Hyponyms: cup_final.n.01
#
#
# Word: burst
# Synonyms: explosion,burst
# Antonyms:
# Hypernyms: change_of_integrity.n.01
# Hyponyms: detonation.n.02,fulmination.n.02
#
#
# Word: banished
# Synonyms: banish,ban,ostracize,ostracise,shun,cast_out,blackball
# Antonyms:
# Hypernyms: expel.v.01
# Hyponyms:
#
#
# Word: heal
# Synonyms: mend,heal
# Antonyms:
# Hypernyms: better.v.03
# Hyponyms:
#
#
# Word: straightening
# Synonyms: straighten,unbend
# Antonyms: bend
# Hypernyms: change_posture.v.01
# Hyponyms:
#
#
# Word: lifting
# Synonyms: raise,lift,elevate,get_up,bring_up
# Antonyms: lower
# Hypernyms: move.v.02
# Hyponyms: chin.v.01,get_up.v.04,heighten.v.04,hike.v.01,hoist.v.01,hoist.v.02,hoist.v.03,jack.v.01,kick_up.v.01,levitate.v.01,pick_up.v.01,pinnacle.v.02,pump.v.07,raise.v.15,rear.v.04,shoulder.v.01,skid.v.02,trice.v.01,underlay.v.01
#
#
# Word: now
# Synonyms: now
# Antonyms:
# Hypernyms: present.n.01
# Hyponyms:
#
#
# Word: shining
# Synonyms: shining,polishing
# Antonyms:
# Hypernyms: work.n.01
# Hyponyms: shoeshine.n.02
#
#
# Word: brightly
# Synonyms: brilliantly,brightly,bright
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: picked
# Synonyms: pick
# Antonyms:
# Hypernyms: choose.v.01
# Hyponyms: hand-pick.v.01
#
#
# Word: flow
# Synonyms: flow,flowing
# Antonyms:
# Hypernyms: change_of_location.n.01
# Hyponyms: airflow.n.01,backflow.n.01,current.n.02,discharge.n.06,drip.n.01,dripping.n.01,ebb.n.02,emission.n.05,flush.n.06,flux.n.02,fountain.n.03,freshet.n.01,overflow.n.02,rush.n.02,seepage.n.01
#
#
# Word: knew
# Synonyms: know,cognize,cognise
# Antonyms: ignore
# Hypernyms:
# Hyponyms: keep_track.v.01,recognize.v.02
#
#
# Word: complete
# Synonyms: complete,finish
# Antonyms:
# Hypernyms: end.v.02
# Hyponyms: carry_through.v.01,close.v.17,follow_through.v.02,get_through.v.01,round_out.v.01,see_through.v.03,top.v.10
#
#
# Word: returned
# Synonyms: return
# Antonyms:
# Hypernyms: travel.v.01
# Hyponyms: backtrack.v.01,boomerang.v.01,bounce.v.04,cut_back.v.01,go_home.v.01,home.v.02,resurrect.v.03,return.v.14,revisit.v.01,trace.v.03
#
#
# Word: greeted
# Synonyms: greet,recognize,recognise
# Antonyms:
# Hypernyms: address.v.09
# Hyponyms: curtsy.v.02,hail.v.04,salute.v.02,salute.v.05,salute.v.06,say_farewell.v.01,shake_hands.v.01,welcome.v.02,wish.v.06
#
#
# Word: pride
# Synonyms: pride,pridefulness
# Antonyms: humility
# Hypernyms: feeling.n.01
# Hyponyms: amour_propre.n.01,dignity.n.01,ego.n.01,self-esteem.n.01
#
#
# Word: gratitude
# Synonyms: gratitude
# Antonyms: ingratitude
# Hypernyms: feeling.n.01
# Hyponyms: gratefulness.n.01
#
#
# Word: saved
# Synonyms: salvage,salve,relieve,save
# Antonyms:
# Hypernyms: rescue.v.01
# Hyponyms:
#
#
# Word: brave
# Synonyms: brave
# Antonyms:
# Hypernyms: warrior.n.01
# Hyponyms:
#
#
# Word: remembered
# Synonyms: remember,retrieve,recall,call_back,call_up,recollect,think
# Antonyms: forget
# Hypernyms:
# Hyponyms: know.v.11,recognize.v.04,review.v.04
#
#
# Word: swelling
# Synonyms: swelling,puffiness,lump
# Antonyms:
# Hypernyms: enlargement.n.02,symptom.n.01
# Hyponyms: bloat.n.01,bunion.n.01,edema.n.01,hematocele.n.01,intumescence.n.01,iridoncus.n.01,lymphogranuloma.n.01,oscheocele.n.01,spermatocele.n.01,tumidity.n.01
#
#
# Word: return
# Synonyms: tax_return,income_tax_return,return
# Antonyms:
# Hypernyms: legal_document.n.01
# Hyponyms: amended_return.n.01,declaration_of_estimated_tax.n.01,false_return.n.01,information_return.n.01,joint_return.n.01
#
#
# Word: waved
# Synonyms: beckon,wave
# Antonyms:
# Hypernyms: gesticulate.v.01
# Hyponyms:
#
#
# Word: reappeared
# Synonyms: reappear,re-emerge
# Antonyms:
# Hypernyms: appear.v.02
# Hyponyms: come_back.v.01,resurface.v.03
#
#
# Word: transported
# Synonyms: transport
# Antonyms:
# Hypernyms: move.v.02
# Hyponyms: advect.v.01,bus.v.01,carry_over.v.02,ferry.v.02,float.v.03,freight.v.01,lighter.v.01,pick_up.v.03,pipe.v.02,raft.v.01,rail.v.05,sledge.v.01,sluice.v.03,teleport.v.01,truck.v.01,wheel.v.02,wheelbarrow.v.01
#
#
# Word: welcomed
# Synonyms: welcome
# Antonyms:
# Hypernyms: accept.v.02
# Hyponyms:
#
#
# Word: left
# Synonyms: left
# Antonyms: right
# Hypernyms: position.n.01
# Hyponyms: stage_left.n.01
#
#
# Word: changed
# Synonyms: change,alter,modify
# Antonyms:
# Hypernyms:
# Hyponyms: accelerate.v.02,acerbate.v.02,acetylate.v.02,achromatize.v.01,activate.v.02,activate.v.03,activate.v.04,activate.v.05,adjust.v.01,affect.v.01,affect.v.02,age.v.03,alchemize.v.01,alcoholize.v.03,alkalinize.v.02,allegorize.v.02,alter.v.03,americanize.v.01,angulate.v.01,animize.v.01,antiquate.v.01,antique.v.02,archaize.v.01,arterialize.v.01,ash.v.01,assimilate.v.03,automatize.v.01,automatize.v.02,awaken.v.01,barb.v.01,barbarize.v.02,bestialize.v.01,better.v.02,blind.v.02,blister.v.03,blunt.v.04,blur.v.02,blur.v.05,boil.v.03,break.v.39,break_down.v.01,brighten.v.01,bring.v.02,bring.v.05,brutalize.v.02,bubble.v.04,calcify.v.04,camp.v.03,capture.v.04,cause_to_sleep.v.01,centralize.v.01,change_intensity.v.01,change_taste.v.01,charge.v.08,charge.v.23,chasten.v.02,check.v.07,circularize.v.05,civilize.v.02,clarify.v.02,classicize.v.01,clean.v.01,clear.v.20,clot.v.02,cloud.v.06,coarsen.v.01,coarsen.v.02,cohere.v.02,color.v.01,commercialize.v.02,communize.v.01,commute.v.04,complicate.v.01,complicate.v.02,condense.v.07,confuse.v.05,constitutionalize.v.03,contaminate.v.02,conventionalize.v.01,convert.v.01,convert.v.02,convert.v.05,cook.v.05,cool.v.01,corrupt.v.01,counterchange.v.01,crack.v.11,cry.v.07,customize.v.02,damage.v.01,darken.v.03,de-emphasize.v.01,deaden.v.03,deaden.v.06,deaminate.v.01,decarboxylate.v.02,decelerate.v.02,decentralize.v.01,decimalize.v.01,decorate.v.01,decrease.v.02,decrepitate.v.02,deflate.v.04,deform.v.01,dehydrogenate.v.01,demagnetize.v.02,demist.v.01,democratize.v.02,demonize.v.01,demulsify.v.01,demythologize.v.01,denationalize.v.01,denaturalize.v.01,denaturalize.v.02,denature.v.01,denature.v.02,denature.v.03,deodorize.v.01,depersonalize.v.01,depolarize.v.01,desensitize.v.01,desensitize.v.02,destabilize.v.02,detransitivize.v.01,devalue.v.02,develop.v.12,develop.v.15,devilize.v.01,digitize.v.01,dinge.v.02,dirty.v.01,disable.v.01,discolor.v.02,disharmonize.v.01,disintegrate.v.02,disorder.v.02,disqualify.v.01,dissimilate.v.02,dissolve.v.07,dissolve.v.11,diversify.v.01,dizzy.v.01,domesticate.v.02,dope.v.02,draw.v.16,dry.v.01,dull.v.01,dull.v.05,dynamize.v.01,dynamize.v.02,ease_up.v.03,edit.v.01,edit.v.03,embrittle.v.01,empty.v.01,emulsify.v.01,enable.v.01,end.v.02,equal.v.03,eroticize.v.01,estrange.v.02,etherealize.v.01,etiolate.v.02,etiolate.v.03,europeanize.v.01,europeanize.v.02,evaporate.v.02,even.v.02,excite.v.07,excite.v.08,extend.v.09,exteriorize.v.02,fatten.v.01,feminize.v.02,fertilize.v.02,fill.v.01,fix.v.12,flatten.v.03,flocculate.v.02,freeze.v.04,frenchify.v.01,full.v.02,gelatinize.v.03,glamorize.v.02,glorify.v.02,habituate.v.02,harmonize.v.06,harshen.v.01,heat.v.01,hue.v.01,humanize.v.01,humble.v.01,hydrogenate.v.01,immaterialize.v.01,immortalize.v.02,inactivate.v.02,incandesce.v.01,increase.v.02,indispose.v.03,industrialize.v.01,inflate.v.03,inform.v.02,inseminate.v.02,insulate.v.01,intensify.v.04,internationalize.v.02,introvert.v.02,invalidate.v.04,invert.v.01,iodinate.v.01,ionate.v.01,islamize.v.01,isomerize.v.01,laicize.v.01,legitimate.v.03,lend.v.01,liberalize.v.01,lifehack.v.01,lift.v.10,liquefy.v.02,loosen.v.01,loosen.v.06,louden.v.02,lower.v.04,lubricate.v.03,magnetize.v.01,make.v.02,make.v.18,make.v.45,mark.v.05,masculinize.v.01,masculinize.v.02,mechanize.v.02,mechanize.v.03,militarize.v.01,militarize.v.02,mince.v.01,mix.v.05,morph.v.01,muddy.v.03,mythologize.v.02,nationalize.v.01,nationalize.v.02,naturalize.v.01,naturalize.v.04,nazify.v.01,neutralize.v.01,neutralize.v.06,nick.v.03,normalize.v.02,obfuscate.v.01,obscure.v.03,obscure.v.05,occidentalize.v.01,officialize.v.01,opacify.v.01,opalize.v.01,opsonize.v.01,orientalize.v.01,ossify.v.03,outmode.v.01,oxidize.v.02,oxygenize.v.01,paganize.v.01,pall.v.05,parallel.v.02,patent.v.03,personalize.v.01,piggyback.v.05,plasticize.v.02,poison.v.03,polarize.v.01,politicize.v.01,port.v.08,professionalize.v.02,proof.v.04,prostrate.v.02,purify.v.02,put.v.02,radicalize.v.01,rarefy.v.01,rarefy.v.02,rationalize.v.05,recombine.v.02,recommend.v.03,reconst ...
#
#
# Word: faced
# Synonyms: confront,face_up,face
# Antonyms: avoid
# Hypernyms: set_about.v.01
# Hyponyms: undertake.v.02
#
#
# Word: victorious
# Synonyms: victorious,winning
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: though
# Synonyms: though
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: spoke
# Synonyms: spoke,wheel_spoke,radius
# Antonyms:
# Hypernyms: support.n.10
# Hyponyms:
#
#
# Word: villager
# Synonyms: villager
# Antonyms:
# Hypernyms: inhabitant.n.01
# Hyponyms:
#
#
# Word: new
# Synonyms: new
# Antonyms: old
# Hypernyms:
# Hyponyms:
#
#
# Word: all
# Synonyms: all
# Antonyms: some,no
# Hypernyms:
# Hyponyms:
#
#
# Word: ahead
# Synonyms: ahead,in_the_lead,leading
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: so
# Synonyms: sol,soh,so
# Antonyms:
# Hypernyms: solfa_syllable.n.01
# Hyponyms:
#
#
# Word: continued
# Synonyms: continue,go_on,proceed,go_along,keep
# Antonyms: discontinue
# Hypernyms: act.v.01
# Hyponyms: hold.v.13,ride.v.03,run_on.v.02
#
#
# Word: explore
# Synonyms: research,search,explore
# Antonyms:
# Hypernyms: investigate.v.01
# Hyponyms: cast_about.v.01,google.v.01,mapquest.v.01,prospect.v.02,re-explore.v.01
#
#
# Word: hoping
# Synonyms: hope,trust,desire
# Antonyms:
# Hypernyms: wish.v.01
# Hyponyms:
#
#
# Word: another
# Synonyms: another,some_other
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: magical
# Synonyms: charming,magic,magical,sorcerous,witching,wizard,wizardly
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: knowing
# Synonyms: knowing
# Antonyms:
# Hypernyms: higher_cognitive_process.n.01
# Hyponyms: awareness.n.01,cognizance.n.02,incognizance.n.01,know.n.01,prevision.n.03,understanding.n.01
#
#
# Word: destined
# Synonyms: destine,fate,doom,designate
# Antonyms:
# Hypernyms: ordain.v.04
# Hyponyms:
